# %% [markdown]
# ## Informações dos vereadores de Jacareí
#
# Análise dos dados das ações dos vereadores disponibilizados no site da Câmara municipal de Jacareí. Neste documento, vamos fazer uma análise de serie temporal, entre os meses de Junho e Agosto.
#
# Neste caso os dados foram baixados e serão carregados de arquivos `CSV`.
#
# `OBS`: Esta análise é feitas apenas para demonstrar funcionalidades do Python e suas bibliotecas, e de como elas ajudam na análise de dados, sendo assim, o que é exposto, é apenas resultado do que está registrado nos dados, sem nenhuma tendência política.

# %%
import pandas as pd
from plotnine import *

# %%
junho = pd.read_csv('../../../dados/dados_remuneracao_vereadores-jacarei/jac_junho_2018.csv')
julho = pd.read_csv('../../../dados/dados_remuneracao_vereadores-jacarei/jac_julho_2018.csv')
agosto = pd.read_csv('../../../dados/dados_remuneracao_vereadores-jacarei/jac_agosto_2018.csv')

# %% [markdown]
# ## Conhecendo os dados
#
# Para começar vamos verificar uma descrição simples dos dados, para ter uma ideia de onde começar a fazer a análise.

# %%
junho.describe()
# Out:
#           Ano  Atendimento aos munícipes  Diárias de Viagens  \
# count    13.0                  13.000000           13.000000
# mean   2018.0                 124.769231           25.384615
# std       0.0                  88.598489           63.410749
# min    2018.0                  41.000000            0.000000
# 25%    2018.0                  66.000000            0.000000
# 50%    2018.0                 115.000000            0.000000
# 75%    2018.0                 146.000000            0.000000
# max    2018.0                 336.000000          198.000000
#
#        Gasolina/Álcool (Litros)  Gasolina/Álcool (R$)  Impressão Colorida  \
# count                 13.000000             13.000000           13.000000
# mean                  77.701692            333.340260          230.615385
# std                   50.213956            215.417871           91.709267
# min                    0.000000              0.000000          114.000000
# ...

# %% [markdown]
# Veja que, conseguimos perceber vários pontos interessantes, veja a quantidade de atendimentos, os gastos com escritórios, e muito mais, e isto tudo, apenas no mês de junho.
#
# Vamos começar analisando os vereadores que mais atendem os munícipes, inicialmente no mês de junho, depois faremos uma análise temporal, dentre os meses analisados.

# %%
atendimentos_junho = junho[['Atendimento aos munícipes', 'Vereador']]

# %%
atendimentos_junho.sort_values('Atendimento aos munícipes', ascending = False)
# Out:
#     Atendimento aos munícipes                         Vereador
# 12                        336         Valmir do Pq.   Meia Lua
# 10                        262          Paulinho dos Condutores
# 1                         162          Aderbal           Sodré
# 11                        146  Sônia Patas          da Amizade
# 7                         132           Lucimar       Ponciano
# 5                         126       Fernando da Ótica Original
# 9                         115              Paulinho do Esporte
# 8                          77                      Luís Flávio
# 3                          72               Dra. Márcia Santos
# 2                          66       Arildo             Batista
# 6                          46          Juarez           Araújo
# 0                          41               Abner de Madureira
# 4                          41              Dr. Rodrigo Salomon

# %% [markdown]
# Para transformar a visualização em algo legal, vamos fazer um plot de barras, com cada vereador e sua quantidade de antendimento no mês de Junho

# %%
(ggplot(atendimentos_junho, aes(x = 'Vereador', y='Atendimento aos munícipes')) + 
     geom_bar(stat = "identity") + coord_flip()
)
# Out:
# <ggplot: (8737956338240)>

# %% [markdown]
# Olha que assim é mais bacana de realizar a visualização dos dados do conjunto de dados. Pois é, então agora já sabemos qual é a quantidade de atendimento que cada vereador vez no mês de junho de 2018, mas será que este número é parecido nos outros meses ?
#
# Vamos agora começar a trabalhar com uma pequena serie temporal utilizando o Pandas. Para isto vamos juntar os dados, todos em um único DataFrame.
#
# `OBS`: Apenas uma dica, aqui vamos simplesmente fazer esta junção, pois verificamos que, os dados dos vereadores estão separados em ordem alfabética :D

# %%
atendimentos_series = pd.concat([junho[['Atendimento aos munícipes', 'Mês', 'Vereador']], 
                                 julho[['Atendimento aos munícipes', 'Mês', 'Vereador']],
                                 agosto[['Atendimento aos munícipes', 'Mês', 'Vereador']]])

# %% [markdown]
# Para deixar organizado, vamos mudar o nome dos vereadores, isto porque, como foi possível perceber no plot acima, os nomes te vários espaços, o comando abaixo trata este problema.

# %%
atendimentos_series['Vereador'] = atendimentos_series['Vereador'].apply(lambda x: x.replace('  ', ''))

# %% [markdown]
# O que eu fiz, foi basicamente aplicar a função declarada dentro do `lambda`, em todos os elementos da coluna `Vereador`. O que a função faz é basicamente remover os espaços.

# %% [markdown]
# Após a junção dos DataFrames, e o tratamento dos nomes, vamos fazer o plot da junção que foi feita.

# %% [markdown]
# Com o agrupamento feito, vamos direto para o plot, para verificar se há muita diferença.

# %%
(ggplot(atendimentos_series, aes(fill='Mês', y = 'Atendimento aos munícipes', x = 'Vereador', width=.7)) 
     + geom_bar(stat="identity", position = 'dodge') + coord_flip())
# Out:
# <ggplot: (-9223363298898468015)>

# %% [markdown]
# Com poucos comandos já fizemos uma análise de serie temporal deste conjunto de dados =D, além dos atendimentos é interessante saber também, o gasto com telefonia de cada vereador, dentre os meses analisados. Vamos lá !
#
# Vou começar juntanto todo o conjunto de dados, assim como fizemos acima, porém agora com informações diferentes. Estas especificadas dentro da lista `chaves`.

# %%
chaves = ['Mês', 'Vereador', 'Telefonia Móvel', 'Telefonia Fixa']

telefonia = pd.concat([
    junho[chaves], julho[chaves], agosto[chaves]
])

# %%
telefonia.head()
# Out:
#      Mês                    Vereador  Telefonia Móvel  Telefonia Fixa
# 0  Junho          Abner de Madureira            19.81           91.43
# 1  Junho     Aderbal           Sodré            18.08           86.64
# 2  Junho  Arildo             Batista            15.18          125.10
# 3  Junho          Dra. Márcia Santos             2.48           67.48
# 4  Junho         Dr. Rodrigo Salomon            11.17           71.44

# %% [markdown]
# Agora, temos em um único DataFrame, todos os meses e gastos com telefonia (Móvel e fixa). Bem vamos agora, criar uma tabela em `long format`, este que, todos os atributos são postos como valores dentro da tabela.
#
# Para isto, será utilizado o método `melt` presente na classe `Pandas` (Aqui nomeada de pd). Básicamente, os valores colocados na tabela serão os tipos de telefonia (Móvel e fixa), em posições que possuem valores do tipo colocado.

# %%
telefonia_series = pd.melt(df, id_vars = ['Vereador', 'Mês'], value_vars = ['Telefonia Móvel', 'Telefonia Fixa'], 
               value_name='valor', var_name = 'Tipo')

# Aqui também é feito a organização dos nomes dos vereadores
telefonia_series['Vereador'] = telefonia_series['Vereador'].apply(lambda x: x.replace('  ', ''))

# %%
telefonia_series.head(5)
# Out:
#               Vereador    Mês             Tipo  valor
# 0   Abner de Madureira  Junho  Telefonia Móvel  19.81
# 1        Aderbal Sodré  Junho  Telefonia Móvel  18.08
# 2       Arildo Batista  Junho  Telefonia Móvel  15.18
# 3   Dra. Márcia Santos  Junho  Telefonia Móvel   2.48
# 4  Dr. Rodrigo Salomon  Junho  Telefonia Móvel  11.17

# %% [markdown]
# Veja que agora há uma nova coluna chamada de `Tipo`, e esta representa o tipo do gasto de cada vereador. Para finalizar, vamos fazer um plot, que cria um `grid` de cada vereador, e seu gasto (E os tipos) em cada mês analisado.

# %%
(ggplot(telefonia_series, aes(y='valor', x = 'Mês', fill='Tipo')) 
     + geom_bar(stat = 'identity', position='dodge') + facet_wrap('Vereador')
     + theme(strip_text = element_text(size=6)))
# Out:
# <ggplot: (8737946438948)>

# %% [markdown]
# Esta análise pode continuar! Existem diversas informações que precisam ser identificadas nestes dados, como os gastos gerais, ou com cada atributo que ainda não foi analisado.
